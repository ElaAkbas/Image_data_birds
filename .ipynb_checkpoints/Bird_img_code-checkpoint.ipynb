# %%
#import modules

import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os 
# %matplotlib inline
from PIL import Image
from numpy import asarray
import numpy as np 
import csv
def change(string):
    result = ''
    for i in range(len(string)):
        if string[i] == "\\":
            result += '/'
        else:
            result += string[i]
    return result[2:] if result[0] == 'C' else result

# %%
#checking the csv 
df = pd.read_csv('/Users/elanu/Desktop/data/Bird images (kaggle)/birds.csv')
df.head(350)
# Out:
#      class id                                 filepaths  \
# 0           0             train/ABBOTTS BABBLER/001.jpg
# 1           0             train/ABBOTTS BABBLER/002.jpg
# 2           0             train/ABBOTTS BABBLER/003.jpg
# 3           0             train/ABBOTTS BABBLER/004.jpg
# 4           0             train/ABBOTTS BABBLER/005.jpg
# ..        ...                                       ...
# 345         1               train/ABBOTTS BOOBY/180.jpg
# 346         2  train/ABYSSINIAN GROUND HORNBILL/001.jpg
# 347         2  train/ABYSSINIAN GROUND HORNBILL/002.jpg
# 348         2  train/ABYSSINIAN GROUND HORNBILL/003.jpg
# 349         2  train/ABYSSINIAN GROUND HORNBILL/004.jpg
#
#                          labels      scientific label data set
# 0               ABBOTTS BABBLER  Malacocincla abbotti    train
# 1               ABBOTTS BABBLER  Malacocincla abbotti    train
# 2               ABBOTTS BABBLER  Malacocincla abbotti    train
# ...

# %%
#test with one image convert and convert back
#img from code above
numpydata = asarray(img)

print(type(numpydata))

 # shape
print(numpydata.shape)

# # Below is the way of creating Pillow
# image from our numpyarray
pilImage = Image.fromarray(numpydata)
print(type(pilImage))

# # Let us check image details
print(pilImage.mode)
print(pilImage.size)
imgplot = plt.imshow(pilImage)

# %%
bird_img_datalist = [['file', 'label', 'data_set']] #creating a header(s) for the final csv files

files_dir = change(r'C:\Users\elanu\Desktop\data\Bird images (kaggle)') #changing directory with function \ > /
os.chdir(files_dir) #working in this directory

with open(files_dir + '/birds.csv', 'r') as csvfile: #open provided birds csv file for all images from train,test and valid
    filedatareader = csv.reader(csvfile, delimiter=',', quotechar='|') 
    for row in filedatareader:
        each_row = []   #per loop adding a row of: numpy, label and type of data_set(train,test or valid)
        fname = row[1]  #row[1] is under filepaths, create fname to create path under this line
        image_path = files_dir + '/' + fname #path of every image
        if image_path == '/Users/elanu/Desktop/data/Bird images (kaggle)/filepaths': #skip header line
            continue
        else:
            #img = mpimg.imread(image_path)
            image = Image.open(image_path) #open image
            image_array = np.array(image)  #make array of image
            each_row.append(image_array)   #add arrays to first column
            each_row.append(row[2])        #add labels to second column
            each_row.append(row[4])        #add data_set to third column
        bird_img_datalist.append(each_row) #add whole row to the datalist

os.chdir(r'C:\Users\elanu\Desktop\bird_rep')
with open('bird_img_data.csv', 'w') as f: #create bird_img_data.csv file
    write = csv.writer(f) 
    write.writerows(bird_img_datalist)

# %%
for i in bird_img_datalist[:5]:
    print(i) #just for checking purposes

# %%
df = pd.read_csv('/Users/elanu/Desktop/bird_rep/bird_img_data.csv')
df.head(350) #just for checking purposes
# Out:
#                                                   file  \
# 0    [[[180 172 149]\r\n  [186 178 155]\r\n  [187 1...
# 1    [[[ 37  62  33]\r\n  [ 39  64  35]\r\n  [ 39  ...
# 2    [[[238 238 230]\r\n  [237 237 229]\r\n  [238 2...
# 3    [[[168 181 137]\r\n  [175 188 144]\r\n  [178 1...
# 4    [[[168 181 137]\r\n  [175 188 144]\r\n  [178 1...
# ..                                                 ...
# 345  [[[ 81  83  70]\r\n  [ 82  84  71]\r\n  [ 83  ...
# 346  [[[ 94  96  47]\r\n  [ 64  66  17]\r\n  [ 92  ...
# 347  [[[202 176 143]\r\n  [221 193 156]\r\n  [210 1...
# 348  [[[ 97 140 130]\r\n  [ 98 140 136]\r\n  [ 86 1...
# 349  [[[128 138  39]\r\n  [138 148  52]\r\n  [134 1...
#
#                           label data_set
# 0               ABBOTTS BABBLER    train
# 1               ABBOTTS BABBLER    train
# 2               ABBOTTS BABBLER    train
# 3               ABBOTTS BABBLER    train
# 4               ABBOTTS BABBLER    train
# ..                          ...      ...
# ...

# %%
#dividing the bird img datalist by three based on the data_type

train = df.loc[df['data_set']=='train',:] 
test = df.loc[df['data_set']=='test',:]
valid = df.loc[df['data_set']=='valid',:]

#create the three different datasets in bird_rep folder
train.to_csv('/Users/elanu/Desktop/bird_rep/train_image_bird.csv', index=False)
test.to_csv('/Users/elanu/Desktop/bird_rep/test_image_bird.csv', index=False)
valid.to_csv('/Users/elanu/Desktop/bird_rep/valid_iamge_bird.csv',index=False)
